# %%
#%matplotlib inline

# %load_ext autoreload
# %autoreload 2

import time
import os
import logging
#from functools import wraps
from copy import deepcopy
import dill
import sys
import matplotlib.pyplot as plt
import numpy as np
import itertools
import pickle
#from tqdm.autonotebook import tqdm, trange

# from IPython.display import display
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets


# torch packages
import torch
import torch.optim as optim
import torch.nn as nn

from torch.nn.functional import mse_loss, l1_loss
from torch.utils.data import DataLoader
from torchvision import datasets,transforms
from torchvision.transforms import v2
#from torchvision.utils import make_grid
from torchsummary import summary


#import torch.nn.functional as F

FILENAME = 'SIC_latent_check_'

# logging.basicConfig(
#     level=logging.DEBUG,
#     format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
#     handlers=[
#         logging.FileHandler("logs/"+FILENAME+"_" + time.strftime("%Y%m%d-%H%M%S")+ ".txt"),
#         #logging.StreamHandler()  #logs to console as well
#     ]
# )

# # Create a logger
# logger = logging.getLogger(__name__)

#import custom modules
if '../src/modules/' not in sys.path:
    sys.path.append('../src/modules/')

# if '../src/modules/' not in sys.path:
#     sys.path.append('../src/modules/')

from plot_jupyter import contour_compare, contour_data
from data_wrangle import get_days_before, get_test_set, window_mean, get_days_after
from autoenc_lowres import Encoder, Decoder, MLP_enc_SIC, MLP_dec_SIC
from autoenc_highres import Encoder_sharp, Decoder_sharp, Encoder_sharp_1024, Decoder_sharp_1024
from sic_data_functions import get_ice_data, thin_data, iiee_calc, normalise_image

batched_iiee = torch.func.vmap(iiee_calc)
batched_min = torch.func.vmap(torch.min)
batched_max = torch.func.vmap(torch.max)

# %%
#seed for repeatable results
torch.manual_seed(0)

gen1 = torch.Generator().manual_seed(0)

#imported_enc, imported_dec = Encoder, Decoder  # encoder/decoder to be run

imported_enc, imported_dec = Encoder_sharp_1024, Decoder_sharp_1024  # encoder/decoder to be run

#imported_enc, imported_dec = Encoder_sharp, Decoder_sharp  # encoder/decoder to be run

epochs = 1300 #400

# if training needs to be run
run_training = True

run_sharp = True

clamp_yn = True
norm_yn = False

if not run_sharp:
    lowres = 'lowres_'
else:
    lowres = 'sharp_'

if not run_training:
    load_ext = True
    #model_enc = '../outputs/latent_space_verification/enc_lowres_64_1000_20240806-134826'
    #model_dec = '../outputs/latent_space_verification/dec_lowres_64_1000_20240806-134826'
else:
    load_ext = False

# %%
sic_data, m = get_ice_data()

if not run_sharp:
    sic_data,_ = thin_data(sic_data,m,3)
del m

#check data with a plot
# fig_1, ax_1 = plt.subplots(figsize=(5,4))
# ax_1.contourf(sic_data[30][350], cmap=plt.get_cmap('Blues_r'))
# ax_1.set_ylim(314, 0)
# fig_1.show()

#check thinned data with a plot
# plt.contourf(DATA[30][350], cmap=plt.get_cmap('Blues_r'))
# plt.show()

# %%
year = 32 # year within data set
day = 0 # day within year as the starting point 
window = 1 # window-averaging
num_year_data = 32 # number of years worth of data
T_train = 365 * num_year_data  # how many days worth of data needed
batchSize = 210  #215 #batch size for dataloader will vary PC to PC
dim_latent = 64 #2,4,8,16,24,32,
T_test = 365*2
#have run [64]

train_split = int(num_year_data*0.8) * 365
val_split = num_year_data *365 - train_split



# X0_ = get_days_before(DATA, year, day, T_train+window-1) # get days from DATA
# X1_ = get_days_after(DATA, year, day,T_test)

# if window > 1:
#     X0_ = window_mean(X0_, window = window, t = None) # compute window mean, 
#     X1_ = get_test_set(DATA, year, day, window, T_test)

# X0_.shape, X1_.shape



X0_ = get_days_before(sic_data, year, day, T_train+window-1)

all_data = torch.Tensor(X0_)[:,None,:,:]

#mask_tensor = torch.Tensor(np.tile(mask, (X0_.shape[0],1,1,1))).bool()

X1_ = get_days_after(sic_data, year, day,  365*2)

#all_test_data = torch.Tensor(X1_)[:,None,:,:]

all_data_train, all_data_val = torch.utils.data.random_split(all_data, [train_split, val_split], generator=gen1)

#full_all_data = torch.utils.data.ConcatDataset([all_data, v2.functional.vflip(all_data), v2.functional.hflip(all_data)])
#full_data_train, full_data_val = torch.utils.data.random_split(full_all_data, [train_split*3, val_split*3], generator=gen1)

# %%
#train and test dataloaders

train_loader_sic = torch.utils.data.DataLoader(dataset=all_data_train, batch_size=batchSize, shuffle=True)

val_loader_sic  = torch.utils.data.DataLoader(dataset=all_data_val, batch_size=batchSize, shuffle=True)

# train_loader_sic = torch.utils.data.DataLoader(dataset=all_data, batch_size=batchSize, shuffle=True)
# train_loader_sic = torch.utils.data.DataLoader(dataset=full_data_train, batch_size=batchSize, shuffle=True)
# val_loader_sic  = torch.utils.data.DataLoader(dataset=full_data_val, batch_size=batchSize, shuffle=True)

# %%
enc = imported_enc(d_latent=dim_latent)
dec = imported_dec(d_latent=dim_latent)

if torch.cuda.is_available():
    enc.to("cuda")  
    dec.to("cuda")  

if not run_sharp:
    summary(enc, (1,105,105))
else:
    summary(enc, (1,314,314))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 8, 310, 310]             208
#             Conv2d-2          [-1, 8, 306, 306]           1,608
#             Conv2d-3          [-1, 8, 302, 302]           1,608
#        BatchNorm2d-4          [-1, 8, 302, 302]              16
#               ReLU-5          [-1, 8, 302, 302]               0
#             Conv2d-6         [-1, 16, 298, 298]           3,216
#             Conv2d-7         [-1, 16, 294, 294]           6,416
#             Conv2d-8         [-1, 16, 290, 290]           6,416
#          MaxPool2d-9         [-1, 16, 145, 145]               0
#       BatchNorm2d-10         [-1, 16, 145, 145]              32
#              ReLU-11         [-1, 16, 145, 145]               0
#            Conv2d-12           [-1, 32, 74, 74]           4,640
#            Conv2d-13           [-1, 32, 38, 38]           9,248
#            Conv2d-14           [-1, 32, 20, 20]           9,248
#         MaxPool2d-15           [-1, 32, 10, 10]               0
#       BatchNorm2d-16           [-1, 32, 10, 10]              64
#              ReLU-17           [-1, 32, 10, 10]               0
#            Conv2d-18             [-1, 64, 8, 8]          18,496
#            Conv2d-19             [-1, 64, 6, 6]          36,928
#            Conv2d-20             [-1, 64, 4, 4]          36,928
#       BatchNorm2d-21             [-1, 64, 4, 4]             128
#           Flatten-22                 [-1, 1024]               0
#            Linear-23                   [-1, 64]          65,600
#           Sigmoid-24                   [-1, 64]               0
# ================================================================
# Total params: 200,800
# Trainable params: 200,800
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.38
# Forward/backward pass size (MB): 69.57
# Params size (MB): 0.77
# Estimated Total Size (MB): 70.71
# ----------------------------------------------------------------

# %%
def train_model(model_enc,model_dec,epochs, training_dataloader, val_dataloader, 
                autograd, enc_loc, dec_loc, trainloss_loc, valloss_loc,     
                mse_multp = 1.0, mae_multp = 1.0, iiee_multp = 1.0, clamp_img = True, norm_img = False, return_model = False):
    # define loss and parameters
    
    model_enc.train()
    model_dec.train()

    optimiser = autograd(itertools.chain(model_enc.parameters(), model_dec.parameters()), lr=0.0001)

    train_loss = []
    val_loss = []

    val_loss_check = 1e10

    t0 = time.time()

    print('====Training start====')
    for epoch in range(epochs):
        
        total_mseloss, total_maeloss, total_iieeloss = 0.0, 0.0, 0.0

        total_val_loss, total_train_loss = 0.0, 0.0
        
        val_loss_mse, val_loss_mae, val_loss_iiee = 0.0, 0.0, 0.0

        for batch_idx, data in enumerate(training_dataloader):
            # prepare input data
            img = data.to("cuda")
            
            #img = img*mask_tensor[:img.shape[0],...]
            output_en = model_enc(img)
            output = model_dec(output_en)

            if clamp_img == True:
                output_norm = output.clamp(min=0, max= 1)#*mask_tensor
            elif norm_img == True:
                output_norm = normalise_image(output)
            else: 
                output_norm = output
            
            loss_mse = mse_loss(output_norm, img)
            
            loss_mae = l1_loss(img, output_norm)
            
            loss_iiee = torch.sum(batched_iiee(output_norm, img))

            loss = (mse_multp * loss_mse) + (loss_iiee * iiee_multp) + (mae_multp * loss_mae)
            
            optimiser.zero_grad()
            loss.backward()
            optimiser.step()

            # Track this epoch's loss
            total_mseloss += loss_mse.item() * data.shape[0] / len(all_data_train)
            total_maeloss += loss_mae.item() * data.shape[0] / len(all_data_train)
            total_iieeloss += loss_iiee.item() * data.shape[0] / len(all_data_train)
            total_train_loss += (loss_mse.item() + loss_mae.item() + loss_iiee.item()) * data.shape[0] / len(all_data_train)

        train_loss.append([total_mseloss, total_maeloss ,total_iieeloss, total_train_loss])

        t1 = time.time()

        model_enc.eval()
        model_dec.eval()

        with torch.no_grad():
            for batch_idx_val, data_val in enumerate(val_dataloader):

                img_val = data_val.to("cuda")
                
                output_en_val = model_enc(img_val)
                output = model_dec(output_en_val)

                if clamp_img == True:
                    output_norm = output.clamp(min=0, max= 1)#*mask_tensor
                elif norm_img == True:
                    output_norm = normalise_image(output)
                else: 
                    output_norm = output

                val_loss_mse += mse_loss(output_norm, img_val).item() * data_val.shape[0] / len(all_data_val)
                val_loss_mae += l1_loss(output_norm, img_val).item() * data_val.shape[0] / len(all_data_val)
                val_loss_iiee += torch.sum(batched_iiee(output_norm, img_val)).item() * data_val.shape[0] / len(all_data_val)

                total_val_loss += (
                                    (mse_loss(output_norm, img_val).item() * val_loss_mse) + 
                                    (torch.sum(batched_iiee(output_norm, img_val)).item()  * iiee_multp) + 
                                    (torch.sum(l1_loss(output_norm, img_val)).item()  * mae_multp)
                                  ) * data_val.shape[0] / len(all_data_val)

            val_loss.append([val_loss_mse, val_loss_iiee, total_val_loss])

        model_enc.train()
        model_dec.train()

        t2 = time.time()

        #check val error and save model
        if epoch > 0:
            if total_val_loss < val_loss_check:
                torch.save(model_enc, '../' + enc_loc +'intertrain/enc_'+ lowres + str(dim_latent)+'_'+ str(epoch) +'_optimal_' + time.strftime("%Y%m%d"))
                torch.save(model_dec, '../' + dec_loc +'intertrain/dec_'+  lowres + str(dim_latent)+'_'+ str(epoch) +'_optimal_' +  time.strftime("%Y%m%d"))
                
                if os.path.exists('../' + enc_loc +'intertrain/intertrain_model_log.txt') == False:
                    open('../' + enc_loc +'intertrain/intertrain_model_log.txt', "w").close
                    
                with open('../' + enc_loc +'intertrain/intertrain_model_log.txt', "a") as text_file:
                    text_file.write('====> Epoch: {}, Train time: {:.4f}, Val time: {:.4f} \n'.format(epoch, t1-t0, t2-t1))
                    text_file.write('====> Epoch: {} Total loss: {:.4f} MSE Loss: {:.4f} MAE Loss: {:.4f} Val loss: {:.4f} \n'.format(epoch, total_train_loss, total_mseloss, total_maeloss,total_val_loss))
                    text_file.write('../' + enc_loc +'intertrain/enc_'+ lowres + str(dim_latent)+'_'+ str(epoch) +'_optimal_' + time.strftime("%Y%m%d") + '\n')
                    text_file.write('../' + dec_loc +'intertrain/dec_'+  lowres + str(dim_latent)+'_'+ str(epoch) +'_optimal_' +  time.strftime("%Y%m%d")+'\n')
                    text_file.write('\n')
                
                val_loss_check = total_val_loss

        if epoch%10==0:  
            print('====> Epoch: {}, Train time: {:.4f}, Val time: {:.4f}'.format(epoch, t1-t0, t2-t1))
            print('====> Epoch: {} Total loss: {:.4f} MSE Loss: {:.4f} MAE Loss: {:.4f} Val loss: {:.4f}'.format(epoch, total_train_loss, total_mseloss, total_maeloss,total_val_loss))
    
    print('====Training finish====')

    torch.save(model_enc, '../' + enc_loc +'enc_' + lowres + str(dim_latent)+'_'+ str(epochs) +'_' + time.strftime("%Y%m%d-%H%M%S"))
    torch.save(model_dec, '../' + dec_loc +'dec_' + lowres + str(dim_latent)+'_'+ str(epochs) +'_' +  time.strftime("%Y%m%d-%H%M%S"))

    train_loss_np = np.array(train_loss)
    val_loss_np = np.array(val_loss)

    with open('../' + trainloss_loc  + lowres + str(dim_latent)+'_'+ str(epochs) +'_' + time.strftime("%Y%m%d-%H%M%S"), 'wb') as output:
        pickle.dump(train_loss_np, output)

    with open('../' + valloss_loc  + lowres + str(dim_latent)+'_'+ str(epochs) +'_' + time.strftime("%Y%m%d-%H%M%S"), 'wb') as output:
        pickle.dump(val_loss_np, output)

    if return_model:
        return model_enc,model_dec, train_loss , val_loss

# %%
if run_training:

    enc, dec, trainloss,valloss = train_model(
        model_enc = enc,
        model_dec = dec,
        epochs = epochs, 
        training_dataloader = train_loader_sic, 
        val_dataloader = val_loader_sic,
        autograd = optim.AdamW, 
        #enc_loc = 'outputs/latent_space_verification/',
        #dec_loc = 'outputs/latent_space_verification/' , 
        enc_loc = 'outputs/final/',
        dec_loc = 'outputs/final/' , 
        # trainloss_loc = 'outputs/latent_space_verification/train_loss_', 
        # valloss_loc = 'outputs/latent_space_verification/val_loss' , 
        trainloss_loc = 'outputs/final/train_loss_', 
        valloss_loc = 'outputs/final/val_loss_' , 
        mse_multp = 0.0, mae_multp = 1.0, iiee_multp = 1.0,
        clamp_img= clamp_yn,
        norm_img= norm_yn,
        return_model = True
    )
# Out:
# ====Training start====
# c:\ProgramData\miniconda3\envs\autoenc1\Lib\site-packages\torch\autograd\graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# c:\ProgramData\miniconda3\envs\autoenc1\Lib\site-packages\torch\nn\modules\conv.py:952: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv_transpose2d(
# ====> Epoch: 0, Train time: 28.0837, Val time: 1.8953
# ====> Epoch: 0 Total loss: 12304657.9376 MSE Loss: 0.1403 MAE Loss: 0.2948 Val loss: 6038897.1223
# ====> Epoch: 10, Train time: 327.6073, Val time: 1.9032
# ====> Epoch: 10 Total loss: 842233.7479 MSE Loss: 0.0093 MAE Loss: 0.0335 Val loss: 852955.6501
# ====> Epoch: 20, Train time: 628.1245, Val time: 1.9166
# ====> Epoch: 20 Total loss: 644711.8231 MSE Loss: 0.0071 MAE Loss: 0.0275 Val loss: 619614.9873
# ====> Epoch: 30, Train time: 928.6223, Val time: 1.9166
# ====> Epoch: 30 Total loss: 528139.7636 MSE Loss: 0.0062 MAE Loss: 0.0248 Val loss: 527608.6965
# ====> Epoch: 40, Train time: 1229.2033, Val time: 1.9168
# ====> Epoch: 40 Total loss: 502056.2858 MSE Loss: 0.0056 MAE Loss: 0.0232 Val loss: 531095.1614
# ====> Epoch: 50, Train time: 1530.0678, Val time: 1.8999
# ====> Epoch: 50 Total loss: 484108.3852 MSE Loss: 0.0052 MAE Loss: 0.0221 Val loss: 487095.5981
# ====> Epoch: 60, Train time: 1830.6822, Val time: 1.9165
# ====> Epoch: 60 Total loss: 463493.8040 MSE Loss: 0.0048 MAE Loss: 0.0210 Val loss: 406874.9665
# ====> Epoch: 70, Train time: 2131.9132, Val time: 1.9332
# ====> Epoch: 70 Total loss: 392879.7537 MSE Loss: 0.0045 MAE Loss: 0.0199 Val loss: 464402.1072
# ====> Epoch: 80, Train time: 2430.1774, Val time: 1.8835
# ====> Epoch: 80 Total loss: 383278.0766 MSE Loss: 0.0043 MAE Loss: 0.0192 Val loss: 386922.1570
# ====> Epoch: 90, Train time: 2726.5584, Val time: 1.9085
# ====> Epoch: 90 Total loss: 378868.5826 MSE Loss: 0.0042 MAE Loss: 0.0190 Val loss: 429543.6945
# ====> Epoch: 100, Train time: 3023.1565, Val time: 1.8830
# ====> Epoch: 100 Total loss: 367169.7910 MSE Loss: 0.0039 MAE Loss: 0.0183 Val loss: 362553.9774
# ====> Epoch: 110, Train time: 3319.1872, Val time: 1.8835
# ====> Epoch: 110 Total loss: 363757.9205 MSE Loss: 0.0038 MAE Loss: 0.0180 Val loss: 375221.1420
# ====> Epoch: 120, Train time: 3618.0017, Val time: 1.8834
# ====> Epoch: 120 Total loss: 344811.4007 MSE Loss: 0.0037 MAE Loss: 0.0178 Val loss: 313766.1845
# ====> Epoch: 130, Train time: 3914.3326, Val time: 1.8837
# ====> Epoch: 130 Total loss: 291654.5934 MSE Loss: 0.0036 MAE Loss: 0.0172 Val loss: 288421.5378
# ====> Epoch: 140, Train time: 4210.7471, Val time: 1.8833
# ====> Epoch: 140 Total loss: 285677.5594 MSE Loss: 0.0035 MAE Loss: 0.0168 Val loss: 294206.6882
# ====> Epoch: 150, Train time: 4506.9616, Val time: 1.8834
# ====> Epoch: 150 Total loss: 281265.0621 MSE Loss: 0.0034 MAE Loss: 0.0165 Val loss: 291162.8526
# ====> Epoch: 160, Train time: 4802.9774, Val time: 1.8876
# ====> Epoch: 160 Total loss: 275347.9384 MSE Loss: 0.0033 MAE Loss: 0.0162 Val loss: 294664.4427
# ====> Epoch: 170, Train time: 5099.4572, Val time: 1.9000
# ====> Epoch: 170 Total loss: 268676.9051 MSE Loss: 0.0032 MAE Loss: 0.0159 Val loss: 266757.9611
# ====> Epoch: 180, Train time: 5395.8719, Val time: 1.8691
# ====> Epoch: 180 Total loss: 271464.5650 MSE Loss: 0.0032 MAE Loss: 0.0161 Val loss: 287849.3588
# ====> Epoch: 190, Train time: 5692.0707, Val time: 1.8982
# ====> Epoch: 190 Total loss: 268354.0552 MSE Loss: 0.0031 MAE Loss: 0.0159 Val loss: 288887.2509
# ====> Epoch: 200, Train time: 5988.0156, Val time: 1.8833
# ====> Epoch: 200 Total loss: 260931.7457 MSE Loss: 0.0030 MAE Loss: 0.0155 Val loss: 255396.2485
# ====> Epoch: 210, Train time: 6284.1812, Val time: 1.8833
# ====> Epoch: 210 Total loss: 256604.9114 MSE Loss: 0.0029 MAE Loss: 0.0154 Val loss: 290562.9648
# ====> Epoch: 220, Train time: 6580.4056, Val time: 1.8566
# ====> Epoch: 220 Total loss: 257520.4572 MSE Loss: 0.0029 MAE Loss: 0.0154 Val loss: 262187.2629
# ====> Epoch: 230, Train time: 6876.2432, Val time: 1.8669
# ====> Epoch: 230 Total loss: 252518.1670 MSE Loss: 0.0029 MAE Loss: 0.0151 Val loss: 266822.8513
# ====> Epoch: 240, Train time: 7172.4076, Val time: 1.8669
# ====> Epoch: 240 Total loss: 253729.2482 MSE Loss: 0.0029 MAE Loss: 0.0152 Val loss: 315750.3336
# ====> Epoch: 250, Train time: 7468.5387, Val time: 1.8856
# ====> Epoch: 250 Total loss: 251615.8234 MSE Loss: 0.0028 MAE Loss: 0.0151 Val loss: 275013.7151
# ====> Epoch: 260, Train time: 7764.8053, Val time: 1.8825
# ====> Epoch: 260 Total loss: 249233.3197 MSE Loss: 0.0028 MAE Loss: 0.0150 Val loss: 256263.9467
# ====> Epoch: 270, Train time: 8060.7676, Val time: 1.8832
# ====> Epoch: 270 Total loss: 245873.6723 MSE Loss: 0.0027 MAE Loss: 0.0148 Val loss: 260413.9059
# ====> Epoch: 280, Train time: 8356.8488, Val time: 1.9001
# ====> Epoch: 280 Total loss: 247586.8483 MSE Loss: 0.0028 MAE Loss: 0.0149 Val loss: 246969.9191
# ====> Epoch: 290, Train time: 8653.1963, Val time: 1.8834
# ====> Epoch: 290 Total loss: 243725.8481 MSE Loss: 0.0027 MAE Loss: 0.0147 Val loss: 279168.6067
# ====> Epoch: 300, Train time: 8948.9606, Val time: 1.8667
# ====> Epoch: 300 Total loss: 239886.2275 MSE Loss: 0.0026 MAE Loss: 0.0145 Val loss: 247129.9196
# ====> Epoch: 310, Train time: 9244.9086, Val time: 1.8667
# ====> Epoch: 310 Total loss: 238347.0943 MSE Loss: 0.0026 MAE Loss: 0.0144 Val loss: 254320.1535
# ====> Epoch: 320, Train time: 9541.2560, Val time: 1.9033
# ====> Epoch: 320 Total loss: 239428.4604 MSE Loss: 0.0026 MAE Loss: 0.0145 Val loss: 236435.2613
# ====> Epoch: 330, Train time: 9837.5861, Val time: 1.8677
# ====> Epoch: 330 Total loss: 237032.2081 MSE Loss: 0.0026 MAE Loss: 0.0143 Val loss: 252310.8917
# ====> Epoch: 340, Train time: 10133.6532, Val time: 1.8855
# ====> Epoch: 340 Total loss: 233460.3504 MSE Loss: 0.0025 MAE Loss: 0.0142 Val loss: 238310.6036
# ====> Epoch: 350, Train time: 10429.4492, Val time: 1.8885
# ====> Epoch: 350 Total loss: 235283.3905 MSE Loss: 0.0025 MAE Loss: 0.0143 Val loss: 237654.1520
# ====> Epoch: 360, Train time: 10725.7804, Val time: 1.8499
# ====> Epoch: 360 Total loss: 234285.0309 MSE Loss: 0.0025 MAE Loss: 0.0142 Val loss: 233272.6858
# ====> Epoch: 370, Train time: 11021.7614, Val time: 1.8825
# ====> Epoch: 370 Total loss: 233844.3033 MSE Loss: 0.0025 MAE Loss: 0.0142 Val loss: 280284.5923
# ====> Epoch: 380, Train time: 11317.5277, Val time: 1.8985
# ====> Epoch: 380 Total loss: 230544.8915 MSE Loss: 0.0024 MAE Loss: 0.0140 Val loss: 325975.8135
# ====> Epoch: 390, Train time: 11613.9070, Val time: 1.9000
# ====> Epoch: 390 Total loss: 228947.3238 MSE Loss: 0.0024 MAE Loss: 0.0140 Val loss: 238132.0559
# ====> Epoch: 400, Train time: 11910.2881, Val time: 1.8833
# ====> Epoch: 400 Total loss: 227254.9434 MSE Loss: 0.0024 MAE Loss: 0.0139 Val loss: 258489.8122
# ====> Epoch: 410, Train time: 12206.7192, Val time: 1.9001
# ====> Epoch: 410 Total loss: 229181.6383 MSE Loss: 0.0024 MAE Loss: 0.0140 Val loss: 228516.4660
# ====> Epoch: 420, Train time: 12502.4405, Val time: 1.8930
# ====> Epoch: 420 Total loss: 224312.7196 MSE Loss: 0.0023 MAE Loss: 0.0137 Val loss: 237418.3021
# ====> Epoch: 430, Train time: 12798.7145, Val time: 1.8667
# ====> Epoch: 430 Total loss: 225405.0929 MSE Loss: 0.0024 MAE Loss: 0.0138 Val loss: 234559.7539
# ====> Epoch: 440, Train time: 13094.9290, Val time: 1.8832
# ====> Epoch: 440 Total loss: 223517.9602 MSE Loss: 0.0023 MAE Loss: 0.0137 Val loss: 253187.1654
# ====> Epoch: 450, Train time: 13390.6957, Val time: 1.8645
# ====> Epoch: 450 Total loss: 221510.4521 MSE Loss: 0.0023 MAE Loss: 0.0136 Val loss: 236008.6857
# ====> Epoch: 460, Train time: 13686.8734, Val time: 1.8844
# ====> Epoch: 460 Total loss: 222383.8050 MSE Loss: 0.0023 MAE Loss: 0.0136 Val loss: 263566.3867
# ====> Epoch: 470, Train time: 13983.6224, Val time: 1.8998
# ====> Epoch: 470 Total loss: 221985.3836 MSE Loss: 0.0023 MAE Loss: 0.0136 Val loss: 269680.2496
# ====> Epoch: 480, Train time: 14280.1699, Val time: 1.9000
# ====> Epoch: 480 Total loss: 220232.6914 MSE Loss: 0.0023 MAE Loss: 0.0136 Val loss: 227224.1652
# ====> Epoch: 490, Train time: 14576.2844, Val time: 1.9002
# ====> Epoch: 490 Total loss: 222873.8111 MSE Loss: 0.0023 MAE Loss: 0.0137 Val loss: 229161.8778
# ====> Epoch: 500, Train time: 14872.2653, Val time: 1.8999
# ====> Epoch: 500 Total loss: 218554.1511 MSE Loss: 0.0022 MAE Loss: 0.0135 Val loss: 225959.3710
# ====> Epoch: 510, Train time: 15168.5823, Val time: 1.9475
# ====> Epoch: 510 Total loss: 217917.6940 MSE Loss: 0.0022 MAE Loss: 0.0134 Val loss: 215204.0411
# ====> Epoch: 520, Train time: 15464.6971, Val time: 1.8806
# ====> Epoch: 520 Total loss: 218755.7884 MSE Loss: 0.0022 MAE Loss: 0.0135 Val loss: 234032.3705
# ====> Epoch: 530, Train time: 15760.5252, Val time: 1.8856
# ====> Epoch: 530 Total loss: 216522.4907 MSE Loss: 0.0022 MAE Loss: 0.0134 Val loss: 238964.7821
# ====> Epoch: 540, Train time: 16056.5563, Val time: 1.9001
# ====> Epoch: 540 Total loss: 213898.1157 MSE Loss: 0.0022 MAE Loss: 0.0132 Val loss: 238372.2073
# ====> Epoch: 550, Train time: 16352.8207, Val time: 1.8834
# ====> Epoch: 550 Total loss: 218450.3390 MSE Loss: 0.0022 MAE Loss: 0.0134 Val loss: 222004.0415
# ====> Epoch: 560, Train time: 16648.9850, Val time: 1.8835
# ====> Epoch: 560 Total loss: 215785.2955 MSE Loss: 0.0022 MAE Loss: 0.0133 Val loss: 246056.6307
# ====> Epoch: 570, Train time: 16944.7161, Val time: 1.8833
# ====> Epoch: 570 Total loss: 213024.0597 MSE Loss: 0.0022 MAE Loss: 0.0132 Val loss: 341088.7214
# ====> Epoch: 580, Train time: 17241.0472, Val time: 1.8835
# ====> Epoch: 580 Total loss: 213546.8850 MSE Loss: 0.0022 MAE Loss: 0.0132 Val loss: 211900.6847
# ====> Epoch: 590, Train time: 17537.1449, Val time: 1.8833
# ====> Epoch: 590 Total loss: 212245.8164 MSE Loss: 0.0021 MAE Loss: 0.0132 Val loss: 212947.3015
# ====> Epoch: 600, Train time: 17832.9593, Val time: 1.8667
# ====> Epoch: 600 Total loss: 212077.9479 MSE Loss: 0.0021 MAE Loss: 0.0132 Val loss: 214033.2738
# ====> Epoch: 610, Train time: 18128.8087, Val time: 1.8982
# ====> Epoch: 610 Total loss: 211754.3775 MSE Loss: 0.0021 MAE Loss: 0.0132 Val loss: 219688.0545
# ====> Epoch: 620, Train time: 18425.2048, Val time: 1.9000
# ====> Epoch: 620 Total loss: 210085.7116 MSE Loss: 0.0021 MAE Loss: 0.0131 Val loss: 312412.5237
# ====> Epoch: 630, Train time: 18721.6192, Val time: 1.8834
# ====> Epoch: 630 Total loss: 209215.9965 MSE Loss: 0.0021 MAE Loss: 0.0130 Val loss: 216846.1232
# ====> Epoch: 640, Train time: 19017.5279, Val time: 1.8889
# ====> Epoch: 640 Total loss: 211101.2514 MSE Loss: 0.0021 MAE Loss: 0.0131 Val loss: 303414.8122
# ====> Epoch: 650, Train time: 19314.7489, Val time: 1.9105
# ====> Epoch: 650 Total loss: 208939.2617 MSE Loss: 0.0021 MAE Loss: 0.0130 Val loss: 211939.6987
# ====> Epoch: 660, Train time: 19613.4994, Val time: 1.8822
# ====> Epoch: 660 Total loss: 206956.7213 MSE Loss: 0.0021 MAE Loss: 0.0129 Val loss: 239172.5219
# ====> Epoch: 670, Train time: 19911.6768, Val time: 1.9306
# ====> Epoch: 670 Total loss: 208223.9592 MSE Loss: 0.0021 MAE Loss: 0.0130 Val loss: 220434.9321
# ====> Epoch: 680, Train time: 20209.4247, Val time: 1.9163
# ====> Epoch: 680 Total loss: 206218.6062 MSE Loss: 0.0021 MAE Loss: 0.0129 Val loss: 219749.4665
# ====> Epoch: 690, Train time: 20507.3052, Val time: 1.8939
# ====> Epoch: 690 Total loss: 208233.4590 MSE Loss: 0.0021 MAE Loss: 0.0130 Val loss: 335139.5690
# ====> Epoch: 700, Train time: 20804.3198, Val time: 1.8835
# ====> Epoch: 700 Total loss: 204798.4483 MSE Loss: 0.0020 MAE Loss: 0.0129 Val loss: 205191.1920
# ====> Epoch: 710, Train time: 21100.2841, Val time: 1.8834
# ====> Epoch: 710 Total loss: 206235.0303 MSE Loss: 0.0021 MAE Loss: 0.0129 Val loss: 206183.3284
# ====> Epoch: 720, Train time: 21396.5475, Val time: 1.9010
# ====> Epoch: 720 Total loss: 204272.3902 MSE Loss: 0.0020 MAE Loss: 0.0128 Val loss: 217512.8626
# ====> Epoch: 730, Train time: 21694.1747, Val time: 1.8796
# ====> Epoch: 730 Total loss: 202383.5703 MSE Loss: 0.0020 MAE Loss: 0.0127 Val loss: 211217.3566
# ====> Epoch: 740, Train time: 21992.0319, Val time: 1.8959
# ====> Epoch: 740 Total loss: 204498.0729 MSE Loss: 0.0020 MAE Loss: 0.0128 Val loss: 220588.8352
# ====> Epoch: 750, Train time: 22290.0582, Val time: 1.8833
# ====> Epoch: 750 Total loss: 202394.9829 MSE Loss: 0.0020 MAE Loss: 0.0127 Val loss: 206508.9722
# ====> Epoch: 760, Train time: 22589.1735, Val time: 1.9069
# ====> Epoch: 760 Total loss: 203646.2641 MSE Loss: 0.0020 MAE Loss: 0.0128 Val loss: 248637.6345
# ====> Epoch: 770, Train time: 22883.9199, Val time: 1.8620
# ====> Epoch: 770 Total loss: 202493.2432 MSE Loss: 0.0020 MAE Loss: 0.0127 Val loss: 205505.4928
# ====> Epoch: 780, Train time: 23177.1733, Val time: 1.8641
# ====> Epoch: 780 Total loss: 201973.0207 MSE Loss: 0.0020 MAE Loss: 0.0127 Val loss: 210736.6174
# ====> Epoch: 790, Train time: 23472.3225, Val time: 1.8650
# ====> Epoch: 790 Total loss: 203248.7792 MSE Loss: 0.0020 MAE Loss: 0.0128 Val loss: 242968.6855
# ====> Epoch: 800, Train time: 23774.8511, Val time: 2.0156
# ====> Epoch: 800 Total loss: 201955.6711 MSE Loss: 0.0020 MAE Loss: 0.0127 Val loss: 204216.3967
# ====> Epoch: 810, Train time: 24084.4425, Val time: 1.9497
# ====> Epoch: 810 Total loss: 200404.7406 MSE Loss: 0.0020 MAE Loss: 0.0126 Val loss: 207735.9173
# ====> Epoch: 820, Train time: 24389.6895, Val time: 1.9131
# ====> Epoch: 820 Total loss: 201079.7242 MSE Loss: 0.0020 MAE Loss: 0.0126 Val loss: 216867.3976
# ====> Epoch: 830, Train time: 24684.2547, Val time: 1.8538
# ====> Epoch: 830 Total loss: 199890.6803 MSE Loss: 0.0020 MAE Loss: 0.0126 Val loss: 208098.5610
# ====> Epoch: 840, Train time: 24977.9965, Val time: 1.8769
# ====> Epoch: 840 Total loss: 198677.7235 MSE Loss: 0.0019 MAE Loss: 0.0125 Val loss: 211960.6296
# ====> Epoch: 850, Train time: 25278.7270, Val time: 1.9946
# ====> Epoch: 850 Total loss: 198326.4084 MSE Loss: 0.0019 MAE Loss: 0.0125 Val loss: 217179.6433
# ====> Epoch: 860, Train time: 25577.7327, Val time: 1.9202
# ====> Epoch: 860 Total loss: 199109.3728 MSE Loss: 0.0019 MAE Loss: 0.0125 Val loss: 199837.8350
# ====> Epoch: 870, Train time: 25876.8838, Val time: 1.8898
# ====> Epoch: 870 Total loss: 197886.0692 MSE Loss: 0.0019 MAE Loss: 0.0125 Val loss: 218742.4111
# ====> Epoch: 880, Train time: 26174.8456, Val time: 1.8989
# ====> Epoch: 880 Total loss: 204524.6220 MSE Loss: 0.0020 MAE Loss: 0.0128 Val loss: 251975.7143
# ====> Epoch: 890, Train time: 26471.3755, Val time: 1.8919
# ====> Epoch: 890 Total loss: 197470.6933 MSE Loss: 0.0019 MAE Loss: 0.0125 Val loss: 440021.5578
# ====> Epoch: 900, Train time: 26767.9578, Val time: 1.8818
# ====> Epoch: 900 Total loss: 199419.5329 MSE Loss: 0.0019 MAE Loss: 0.0126 Val loss: 200081.3982
# ====> Epoch: 910, Train time: 27065.7617, Val time: 1.9923
# ====> Epoch: 910 Total loss: 197446.4626 MSE Loss: 0.0019 MAE Loss: 0.0125 Val loss: 212266.5472
# ====> Epoch: 920, Train time: 27362.5350, Val time: 1.9002
# ====> Epoch: 920 Total loss: 197042.7371 MSE Loss: 0.0019 MAE Loss: 0.0125 Val loss: 220862.1096
# ====> Epoch: 930, Train time: 27661.4326, Val time: 1.9335
# ====> Epoch: 930 Total loss: 199401.6096 MSE Loss: 0.0019 MAE Loss: 0.0126 Val loss: 217342.9589
# ====> Epoch: 940, Train time: 27958.4637, Val time: 1.9162
# ====> Epoch: 940 Total loss: 195355.2318 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 203108.4654
# ====> Epoch: 950, Train time: 28255.6946, Val time: 1.8834
# ====> Epoch: 950 Total loss: 195632.8466 MSE Loss: 0.0019 MAE Loss: 0.0124 Val loss: 198945.6982
# ====> Epoch: 960, Train time: 28555.5785, Val time: 1.8882
# ====> Epoch: 960 Total loss: 194684.6487 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 208539.5608
# ====> Epoch: 970, Train time: 28852.2900, Val time: 1.9068
# ====> Epoch: 970 Total loss: 194831.9956 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 266319.8782
# ====> Epoch: 980, Train time: 29149.1417, Val time: 1.8992
# ====> Epoch: 980 Total loss: 196199.1814 MSE Loss: 0.0019 MAE Loss: 0.0124 Val loss: 205268.9585
# ====> Epoch: 990, Train time: 29446.2599, Val time: 1.8994
# ====> Epoch: 990 Total loss: 194456.8580 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 195958.8482
# ====> Epoch: 1000, Train time: 29743.2829, Val time: 1.9026
# ====> Epoch: 1000 Total loss: 194828.4323 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 210945.5745
# ====> Epoch: 1010, Train time: 30039.9352, Val time: 1.8977
# ====> Epoch: 1010 Total loss: 194838.7238 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 199368.7119
# ====> Epoch: 1020, Train time: 30337.0356, Val time: 1.9040
# ====> Epoch: 1020 Total loss: 193660.1341 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 228133.0563
# ====> Epoch: 1030, Train time: 30636.1339, Val time: 1.8832
# ====> Epoch: 1030 Total loss: 193912.7309 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 195529.5192
# ====> Epoch: 1040, Train time: 30935.9718, Val time: 1.8845
# ====> Epoch: 1040 Total loss: 194454.5353 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 201127.7116
# ====> Epoch: 1050, Train time: 31236.6870, Val time: 2.0550
# ====> Epoch: 1050 Total loss: 193685.0613 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 193965.4371
# ====> Epoch: 1060, Train time: 31544.1296, Val time: 2.0921
# ====> Epoch: 1060 Total loss: 193390.6196 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 195629.9033
# ====> Epoch: 1070, Train time: 31851.4295, Val time: 2.0844
# ====> Epoch: 1070 Total loss: 192986.6130 MSE Loss: 0.0018 MAE Loss: 0.0122 Val loss: 206574.3422
# ====> Epoch: 1080, Train time: 32152.1164, Val time: 1.8548
# ====> Epoch: 1080 Total loss: 192299.6628 MSE Loss: 0.0018 MAE Loss: 0.0122 Val loss: 199373.6022
# ====> Epoch: 1090, Train time: 32444.7666, Val time: 1.8506
# ====> Epoch: 1090 Total loss: 193165.4749 MSE Loss: 0.0018 MAE Loss: 0.0122 Val loss: 233653.9176
# ====> Epoch: 1100, Train time: 32738.1256, Val time: 1.8834
# ====> Epoch: 1100 Total loss: 194091.7599 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 198331.6154
# ====> Epoch: 1110, Train time: 33034.2127, Val time: 1.8892
# ====> Epoch: 1110 Total loss: 191747.0025 MSE Loss: 0.0018 MAE Loss: 0.0122 Val loss: 269311.7830
# ====> Epoch: 1120, Train time: 33330.4708, Val time: 1.8952
# ====> Epoch: 1120 Total loss: 191020.5701 MSE Loss: 0.0018 MAE Loss: 0.0121 Val loss: 205332.0264
# ====> Epoch: 1130, Train time: 33626.8203, Val time: 1.9001
# ====> Epoch: 1130 Total loss: 192044.2792 MSE Loss: 0.0018 MAE Loss: 0.0122 Val loss: 228047.7816
# ====> Epoch: 1140, Train time: 33923.6161, Val time: 1.9171
# ====> Epoch: 1140 Total loss: 191334.0425 MSE Loss: 0.0018 MAE Loss: 0.0122 Val loss: 198052.6977
# ====> Epoch: 1150, Train time: 34219.7470, Val time: 1.8837
# ====> Epoch: 1150 Total loss: 191028.2972 MSE Loss: 0.0018 MAE Loss: 0.0121 Val loss: 212067.8488
# ====> Epoch: 1160, Train time: 34515.9850, Val time: 1.9031
# ====> Epoch: 1160 Total loss: 191129.6518 MSE Loss: 0.0018 MAE Loss: 0.0121 Val loss: 191890.1358
# ====> Epoch: 1170, Train time: 34812.1924, Val time: 1.8988
# ====> Epoch: 1170 Total loss: 192502.1390 MSE Loss: 0.0018 MAE Loss: 0.0122 Val loss: 218770.7122
# ====> Epoch: 1180, Train time: 35108.4233, Val time: 1.8668
# ====> Epoch: 1180 Total loss: 189697.4413 MSE Loss: 0.0018 MAE Loss: 0.0121 Val loss: 237223.8356
# ====> Epoch: 1190, Train time: 35404.4915, Val time: 1.8960
# ====> Epoch: 1190 Total loss: 189654.2270 MSE Loss: 0.0018 MAE Loss: 0.0121 Val loss: 211691.5892
# ====> Epoch: 1200, Train time: 35700.8851, Val time: 1.8862
# ====> Epoch: 1200 Total loss: 194671.1473 MSE Loss: 0.0019 MAE Loss: 0.0123 Val loss: 251327.6581
# ====> Epoch: 1210, Train time: 35997.5661, Val time: 1.8903
# ====> Epoch: 1210 Total loss: 189424.7476 MSE Loss: 0.0018 MAE Loss: 0.0121 Val loss: 199711.1087
# ====> Epoch: 1220, Train time: 36293.9638, Val time: 1.9001
# ====> Epoch: 1220 Total loss: 190484.3783 MSE Loss: 0.0018 MAE Loss: 0.0121 Val loss: 199392.4371
# ====> Epoch: 1230, Train time: 36593.4062, Val time: 1.9070
# ====> Epoch: 1230 Total loss: 189598.4955 MSE Loss: 0.0018 MAE Loss: 0.0121 Val loss: 241363.5752
# ====> Epoch: 1240, Train time: 36891.6750, Val time: 1.9022
# ====> Epoch: 1240 Total loss: 191192.6238 MSE Loss: 0.0018 MAE Loss: 0.0122 Val loss: 198584.6978
# ====> Epoch: 1250, Train time: 37189.3065, Val time: 1.9000
# ====> Epoch: 1250 Total loss: 188058.2395 MSE Loss: 0.0018 MAE Loss: 0.0120 Val loss: 208006.1086
# ====> Epoch: 1260, Train time: 37494.2917, Val time: 2.0380
# ====> Epoch: 1260 Total loss: 189018.9623 MSE Loss: 0.0018 MAE Loss: 0.0120 Val loss: 229335.3573
# ====> Epoch: 1270, Train time: 37798.4848, Val time: 2.0599
# ====> Epoch: 1270 Total loss: 189551.8588 MSE Loss: 0.0018 MAE Loss: 0.0121 Val loss: 210366.2206
# ====> Epoch: 1280, Train time: 38101.1721, Val time: 2.0341
# ====> Epoch: 1280 Total loss: 188045.9781 MSE Loss: 0.0018 MAE Loss: 0.0120 Val loss: 207554.6853
# ====> Epoch: 1290, Train time: 38402.0468, Val time: 1.9000
# ====> Epoch: 1290 Total loss: 190450.3794 MSE Loss: 0.0018 MAE Loss: 0.0121 Val loss: 288335.3029
# ====Training finish====

# %%
if run_training:
    # collect loss and add plot 
    plt.plot(np.array(trainloss)[100:,0], label = "Training Error")
        # plt.legend()
        # plt.show()
    plt.plot(np.array(valloss)[100:,0], label = "Validation Error")
    plt.legend()
    plt.show()

# with open(r'C:\Project\smooth_autoenc\outputs\latent_space_verification\trainloss_lowres_2_1000_20240726-115656', 'rb') as f:
#     train_loss_pkl = pickle.load(f)

# with open(r'C:\Project\smooth_autoenc\outputs\latent_space_verification\vallosslowres_2_1000_20240726-115656', 'rb') as f:
#     val_loss_pkl = pickle.load(f)

# plt.plot(train_loss_pkl[100:,0], label = "Training Error")
# plt.plot(val_loss_pkl[100:,0], label = "Validation Error")
# plt.legend()
# plt.show()

# %%
## load models ###
if load_ext:
    trained_enc = imported_enc()
    trained_dec = imported_dec()

    trained_enc = torch.load(model_enc)
    trained_dec = torch.load(model_dec)
else:
    trained_enc  = enc
    trained_dec = dec

enc.eval()
dec.eval()

trained_enc.eval()
trained_dec.eval()

trained_enc_cpu = trained_enc.cpu()
trained_dec_cpu = trained_dec.cpu()

# %%
def test_data_stats(test_data,clamp_yn, norm_yn, encoder, decorder):

    X_test_all = torch.Tensor(test_data)[:,None,...]

    enc_test = encoder(X_test_all)

    if clamp_yn == True:
        dec_test = decorder(enc_test).clamp(min=0, max= 1)
    elif norm_yn == True:
        dec_test = normalise_image(decorder(enc_test))#*mask_tensor[:730,:,:,:])
    else:
        dec_test = decorder(enc_test)
         
    X_test, dec_test = X_test_all.permute(1,0,2,3)[0], dec_test.permute(1,0,2,3)[0]

    x_true, x_predict = X_test.flatten(), dec_test.flatten()

    err = (x_true - x_predict)**2

    mse_per_img = ((dec_test - X_test)**2).sum(dim=(1,2))/(X_test.shape[2]**2)

    mae_per_img = (torch.abs(dec_test - X_test)).sum(dim=(1,2))/(X_test.shape[2]**2)

    total_err =  err.sum().detach().numpy()
    
    avg_err = total_err/err.shape[0]

    avg_mae = mae_per_img.sum()/mae_per_img.shape[0]

    print("Total square error: {:.4f}, MSE: {:.4f} RMSE: {:.4f}".format(total_err,avg_err, np.sqrt(avg_err)))

    #iiee
    test_iiee = iiee_calc(dec_test, X_test)
    
    iiee_per_img = batched_iiee(dec_test, X_test)

    print("Total iiee: {:.4f}".format(test_iiee))

    return [err,  total_err, avg_err, np.sqrt(avg_err), mse_per_img, mae_per_img, avg_mae, test_iiee, iiee_per_img]

# %%
test_loss_tuple = test_data_stats(X1_,clamp_yn,norm_yn,trained_enc_cpu, trained_dec_cpu)

# with open('../outputs/latent_space_verification/test_loss_'+ lowres   + str(dim_latent)+'_'+ str(epochs) +'_' + time.strftime("%Y%m%d-%H%M%S"), 'wb') as output:
#         pickle.dump(test_loss_tuple, output)

with open('../outputs/final/test_loss_'+ lowres   + str(dim_latent)+'_'+ str(epochs) +'_' + time.strftime("%Y%m%d-%H%M%S"), 'wb') as output:
        pickle.dump(test_loss_tuple, output)
# Out:
# Total square error: 219417.6875, MSE: 0.0030 RMSE: 0.0552
# Total iiee: 986922.0000

# %%
a =
# Out:
#   Cell In[13], line 1
#     a =
#         ^
# SyntaxError: invalid syntax

# %%
enc_test = trained_enc_cpu(torch.Tensor(X1_)[:,None,:,:])
dec_test = trained_dec_cpu(enc_test).clamp(0,1)
dec_test_arr = dec_test.permute(1,0,2,3).detach().numpy()[0]

# %%
contour_compare(X1_, dec_test_arr)

# %%
# enc_train = trained_enc_cpu(all_data)
# dec_train = trained_dec_cpu(enc_train)#.clamp(0,1)
# dec_train_arr = dec_train.permute(1,0,2,3).detach().numpy()[0]

# %%
# contour_compare(X0_, dec_train_arr)

# %%
mse_perimage_chck = ((dec_test_arr - X1_)**2).sum(axis=(1,2))/(X1_.shape[2]**2)

mse_avg_chk = mse_perimage_chck.sum()/X1_.shape[0]
mse_avg_chk

plt.plot(mse_perimage_chck)
plt.show()

iiee_chck = batched_iiee(torch.Tensor(dec_test_arr), torch.Tensor(X1_))

plt.plot(iiee_chck)
plt.show()
